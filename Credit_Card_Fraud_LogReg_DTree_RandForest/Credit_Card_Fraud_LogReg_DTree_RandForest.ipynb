# %% [markdown]
# <div style="background-color:#ffffff; padding:10px; border-radius:5px;">
#     <h2 style="color:#333333; text-align:center;">Background 🌐</h2>
#     <p style="color:#555555; font-size:16px;">
#         European bank collected data on credit card transactions made by European cardholders over two days. Out of <strong>284,807</strong> transactions, <strong>492</strong> were identified as fraudulent, making up only <strong>0.172%</strong> of the total transactions. The dataset includes numerical input variables derived from a Principal Component Analysis (PCA) transformation, with <strong>'Time'</strong> representing the seconds elapsed since the first transaction and <strong>'Amount'</strong> denoting the transaction amount. The response variable <strong>'Class'</strong> equals 1 for fraud and 0 otherwise. Due to confidentiality reasons, the original features and additional background information are unavailable.
#     </p>
#     <p style="color:#555555; font-size:16px;">
#         As a data consultant for this bank, they have assigned you the task of building a robust model that captures these fraudulent transactions. The objective is to develop a system utilizing machine learning algorithms to accurately classify transactions, particularly identifying fraudulent ones. By implementing and evaluating three different models - <strong>Decision Tree (Dtree)</strong>, <strong>Logistic Regression (LogRegression)</strong>, and <strong>Random Forest (RandForest)</strong> - our goal is to enhance security measures for the customers by minimizing the risk of unauthorized transactions and potential financial losses.
#     </p>
# </div>
#
# <div style="background-color:#ffffff; padding:10px; border-radius:5px;">
#     <h2 style="color:#333333; text-align:center;">Objective 📊</h2>
#     <p style="color:#555555; font-size:16px;">
#         The objective is to develop a <strong>robust fraud detection system</strong> for credit card transactions utilizing machine learning algorithms.
#     </p>
# </div>
#
# <div style="background-color:#ffffff; padding:10px; border-radius:5px;">
#     <h2 style="color:#333333; text-align:center;">Goal 🎯</h2>
#     <p style="color:#555555; font-size:16px;">
#         The goal is to <strong>implement and evaluate three different machine learning algorithms</strong>:
#     </p>
#     <ol style="color:#555555; font-size:16px;">
#         <li><strong>Decision Tree (Dtree)</strong></li>
#         <li><strong>Logistic Regression (LogRegression)</strong></li>
#         <li><strong>Random Forest (RandForest)</strong></li>
#     </ol>
#     <p style="color:#555555; font-size:16px;">
#         to predict whether a credit card transaction is legitimate or fraudulent. By leveraging the provided dataset, which contains PCA-transformed numerical features along with <strong>'Time'</strong> and <strong>'Amount'</strong>, our aim is to create models that accurately classify transactions, particularly identifying fraudulent ones. This system aims to enhance security measures for the customers by minimizing the risk of unauthorized transactions and potential financial losses.
#     </p>
# </div>

# %% [markdown]
# <div style="background-color:#f0f0f0; padding:10px; border-radius:5px;">
#     <h2 style="color:#333333; text-align:center;">Technical Report: Credit Card Fraud Detection Model Comparison</h2>
#     <h3 style="color:#555555; text-align:center;">Executive Summary</h3>
#     <p style="color:#555555; font-size:16px; text-align:justify;">
#         This report evaluates three machine learning models for detecting credit card fraud: Logistic Regression with Cross-Validation (LR CV), Decision Tree with Cross-Validation (DT CV), and Random Forest with Cross-Validation (RF CV).
#     </p>
#     <h3 style="color:#555555; text-align:center;">Performance Metrics Summary</h3>
#     <ul style="color:#555555; font-size:16px;">
#         <li>Logistic Regression CV demonstrates balanced metrics, with an F1 Score of <strong>92.9134%</strong>.</li>
#         <li>Decision Tree CV shows the least performance across all metrics except Recall.</li>
#         <li>Random Forest CV exhibits perfect Precision but lower Recall.</li>
#     </ul>
#     <h3 style="color:#555555; text-align:center;">Model Selection</h3>
#     <table style="width:100%; color:#555555; font-size:16px;">
#         <tr>
#             <th>Model</th>
#             <th>Accuracy</th>
#             <th>Precision</th>
#             <th>Recall</th>
#             <th>F1 Score</th>
#         </tr>
#         <tr>
#             <td><strong>Logistic Regression CV(Champion)</strong></td>
#             <td>93.66%</td>
#             <td>95.16%</td>
#             <td>90.77%</td>
#             <td>92.91%</td>
#         </tr>
#         <tr>
#             <td>Decision Tree CV</td>
#             <td>90.14%</td>
#             <td>86.96%</td>
#             <td>92.31%</td>
#             <td>89.55%</td>
#         </tr>
#         <tr>
#             <td>Random Forest CV</td>
#             <td>93.66%</td>
#             <td>100%</td>
#             <td>86.15%</td>
#             <td>92.56%</td>
#         </tr>
#     </table>
#     <p style="color:#555555; font-size:16px; text-align:justify;">
#         The Logistic Regression CV model is recommended due to its balanced approach across all metrics, especially the crucial F1 Score.
#     </p>
#     <h3 style="color:#555555; text-align:center;">Test Set Performance Evaluation</h3>
#     <p style="color:#555555; font-size:16px; text-align:justify;">
#         The champion model, Logistic Regression CV, demonstrated robust performance on the unseen test set with an Accuracy of <strong>93.66%</strong>, Precision of <strong>94.12%</strong>, Recall of <strong>92.75%</strong>, and F1 Score of <strong>93.43%</strong>.
#     </p>
#     <h3 style="color:#555555; text-align:center;">Recommendation</h3>
#     <p style="color:#555555; font-size:16px; text-align:justify;">
#         The Logistic Regression CV model is recommended for deployment in credit card fraud detection systems due to its balanced approach in catching frauds while minimizing disturbance to non-fraudulent transactions.
#     </p>
#     <h3 style="color:#555555; text-align:center;">Future Considerations</h3>
#     <p style="color:#555555; font-size:16px; text-align:justify;">
#         Future work should include a cost-benefit analysis of false positives versus false negatives and continuous monitoring of the model's performance to adapt to changing fraud trends. <strong>We would need to analyze the cost-to-benefit ratio of identifying a card transaction falsely fraudulent, which might lead to account closure of already satisfied customers.</strong> This analysis will provide insights into the potential financial impact of misclassification errors and help optimize the fraud detection system accordingly.
#     </p>
# </div>

# %%
# Data Manipulation imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Pre precosseing import
from sklearn.preprocessing import RobustScaler

# Machine learning imports
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# Evaluation matrics imports
import sklearn.metrics as metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve, auc

# Setting display size
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# ignoring warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Read the data
df = pd.read_csv('creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
# Stats description:
df.describe().apply(lambda s: s.apply('{0:.5f}'.format))
# Out:
#                Time            V1            V2            V3            V4  \
# count  284807.00000  284807.00000  284807.00000  284807.00000  284807.00000
# mean    94813.85958       0.00000       0.00000      -0.00000       0.00000
# std     47488.14595       1.95870       1.65131       1.51626       1.41587
# min         0.00000     -56.40751     -72.71573     -48.32559      -5.68317
# 25%     54201.50000      -0.92037      -0.59855      -0.89036      -0.84864
# 50%     84692.00000       0.01811       0.06549       0.17985      -0.01985
# 75%    139320.50000       1.31564       0.80372       1.02720       0.74334
# max    172792.00000       2.45493      22.05773       9.38256      16.87534
#
#                  V5            V6            V7            V8            V9  \
# count  284807.00000  284807.00000  284807.00000  284807.00000  284807.00000
# mean       -0.00000       0.00000      -0.00000      -0.00000      -0.00000
# ...

# %% [markdown]
# **Observation**:
# - We dont really have anything insightful since the values are trasnformed using PCA.
# - One peculiarity of this dataset is the inclusion of outliers in our analysis. This is becasue an outlier might be the case of a fraudulent transaction. We would want to preserve this to prevent loss of information from our dataset.
# - One thing to note is the values in the `Amount`column; these are on a much differnet scale than the rest of the values. We will transform these values using **Robust Scaler**. Since most of the values are concentrated around zero having a few outliers as the plots range shows, we need to inlcude these values in our analysis for potential frauduleant transaction.
# - With respect to the time scale, since the distribution is even, we will normalize these values to have them from range 0-1.
#
# > By not rescaling all values to the range of 0-1, you're preserving the outliers in the dataset, which is important for detecting potentially fraudulent transactions. Rescaling everything to a common scale could lead to loss of information, particularly regarding outliers, which may be critical for fraud detection.

# %%
# Plot histograms for data 
df.hist(bins=30, figsize = (30,30))
# Out:
# array([[<AxesSubplot:title={'center':'Time'}>,
#         <AxesSubplot:title={'center':'V1'}>,
#         <AxesSubplot:title={'center':'V2'}>,
#         <AxesSubplot:title={'center':'V3'}>,
#         <AxesSubplot:title={'center':'V4'}>,
#         <AxesSubplot:title={'center':'V5'}>],
#        [<AxesSubplot:title={'center':'V6'}>,
#         <AxesSubplot:title={'center':'V7'}>,
#         <AxesSubplot:title={'center':'V8'}>,
#         <AxesSubplot:title={'center':'V9'}>,
#         <AxesSubplot:title={'center':'V10'}>,
#         <AxesSubplot:title={'center':'V11'}>],
#        [<AxesSubplot:title={'center':'V12'}>,
#         <AxesSubplot:title={'center':'V13'}>,
#         <AxesSubplot:title={'center':'V14'}>,
#         <AxesSubplot:title={'center':'V15'}>,
#         <AxesSubplot:title={'center':'V16'}>,
#         <AxesSubplot:title={'center':'V17'}>],
#        [<AxesSubplot:title={'center':'V18'}>,
#         <AxesSubplot:title={'center':'V19'}>,
# ...

# %%
# Changing 'Amount' scale
new_df = df.copy()

new_df['Amount'] = RobustScaler().fit_transform(new_df['Amount'].to_numpy().reshape(-1,1))

new_df['Amount'].hist()
print(new_df['Amount'].describe())
# Out:
# count    284807.000000
# mean          0.927124
# std           3.495006
# min          -0.307413
# 25%          -0.229162
# 50%           0.000000
# 75%           0.770838
# max         358.683155
# Name: Amount, dtype: float64

# %% [markdown]
# **Note**:
# - The rescaled values are not within the range of 0-1 or -1 to 1. Though this is the case, the values have been rescaled from the range of 0-25000 to 0-350.
# - Moreover, the std dev has been reduced from 250 to 3. This change will prove benficial for our modelling phase as the values are more aligned with each other.
# - Furthermore, there are outliers in the dataset as the rescaled values suggest but the potential bias seems to have been reduced as the dsitribution remains the same. This will help our models learn better on our dataset.

# %%
# Changing time scale
time = new_df['Time']
new_df['Time'] = (time - time.min()) / (time.max() - time.min())

# %%
# Overview of change
new_df['Time'].describe()
# Out:
# count    284807.000000
# mean          0.548717
# std           0.274828
# min           0.000000
# 25%           0.313681
# 50%           0.490138
# 75%           0.806290
# max           1.000000
# Name: Time, dtype: float64

# %%
# Checking the distribution once again

new_df.hist(bins = 30, figsize = (30,30))
# Out:
# array([[<AxesSubplot:title={'center':'Time'}>,
#         <AxesSubplot:title={'center':'V1'}>,
#         <AxesSubplot:title={'center':'V2'}>,
#         <AxesSubplot:title={'center':'V3'}>,
#         <AxesSubplot:title={'center':'V4'}>,
#         <AxesSubplot:title={'center':'V5'}>],
#        [<AxesSubplot:title={'center':'V6'}>,
#         <AxesSubplot:title={'center':'V7'}>,
#         <AxesSubplot:title={'center':'V8'}>,
#         <AxesSubplot:title={'center':'V9'}>,
#         <AxesSubplot:title={'center':'V10'}>,
#         <AxesSubplot:title={'center':'V11'}>],
#        [<AxesSubplot:title={'center':'V12'}>,
#         <AxesSubplot:title={'center':'V13'}>,
#         <AxesSubplot:title={'center':'V14'}>,
#         <AxesSubplot:title={'center':'V15'}>,
#         <AxesSubplot:title={'center':'V16'}>,
#         <AxesSubplot:title={'center':'V17'}>],
#        [<AxesSubplot:title={'center':'V18'}>,
#         <AxesSubplot:title={'center':'V19'}>,
# ...

# %% [markdown]
# We have now, rescaled our features appropiately, preserving our outliers for potential fraudulent transactions.

# %% [markdown]
# ## We will now address the imbalance in the dataset for the target class

# %%
# Distribution:
new_df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# We will perform **Downsampling** to match the 492 number of fraudulant transactions

# %%
from sklearn.utils import resample

# Assume df is your dataframe and 'verified_status' is the column with class labels

# Separating the majority and minority classes
data_minority = df[df['Class'] == 1]
data_majority = df[df['Class'] == 0]

# Calculate the number of samples needed from the majority class to achieve 50-50 split
# Let's say we want the majority class to be 60% of the dataset

majority_size = int(len(data_minority) * (50/50)) # note: 60/40 = desired_majority_proportion / desired_minority_proportion

# Downsample majority class to the calculated size
data_downsample_majority = resample(data_majority, 
                                    replace=False,  # sample without replacement
                                    n_samples=majority_size,  # calculated size for desired distribution
                                    random_state=0)  # reproducible results

# Combine minority class with downsampled majority class
data_downsampled = pd.concat([data_downsample_majority, data_minority])

# Resetting the index
data_downsampled = data_downsampled.reset_index(drop=True)

# Displaying the first few rows of the downsampled dataframe
print(data_downsampled['Class'].value_counts())
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
# Making a copy
new_df = data_downsampled.copy()

new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    984 non-null    float64
#  1   V1      984 non-null    float64
#  2   V2      984 non-null    float64
#  3   V3      984 non-null    float64
#  4   V4      984 non-null    float64
#  5   V5      984 non-null    float64
#  6   V6      984 non-null    float64
#  7   V7      984 non-null    float64
#  8   V8      984 non-null    float64
#  9   V9      984 non-null    float64
#  10  V10     984 non-null    float64
#  11  V11     984 non-null    float64
#  12  V12     984 non-null    float64
#  13  V13     984 non-null    float64
#  14  V14     984 non-null    float64
#  15  V15     984 non-null    float64
#  16  V16     984 non-null    float64
#  17  V17     984 non-null    float64
#  18  V18     984 non-null    float64
#  19  V19     984 non-null    float64
# ...

# %% [markdown]
# ## Modelling:
#
# ## Logistic Regression

# %% [markdown]
# Moving on to the modelling phase. We will be using the following models:
#
# - **Logistic Regression**: Logistic Regression is a commonly used algorithm for binary classification tasks like fraud detection. However, it's essential to note that Logistic Regression assumes a linear relationship between the features and the log-odds of the target variable, which may not always hold true. Nevertheless, it's a good starting point for classification tasks.
# - **Decision Trees with Cross-Validation**: Decision Trees are intuitive and easy to interpret, making them suitable for understanding the underlying patterns in the data. By using cross-validation, you're effectively evaluating the model's performance on multiple subsets of the data, which helps in estimating its generalization ability.
# - **Random Forest with Cross-Validation using Grid Search CV**: Random Forest is an ensemble learning method that combines multiple decision trees to improve predictive performance and reduce overfitting. By using cross-validated Grid Search CV, you're tuning the hyperparameters of the Random Forest model to find the best combination that maximizes performance.

# %%
# Since we concatenated datasets[majority and minority classes] we will shuffle the dataset rows for randomization
df_shuffled = new_df.sample(frac=1).reset_index(drop=True)

# Custom split to have equal testing and validation data points
X_train, y_train = df_shuffled.iloc[:700, :-1].values, df_shuffled.iloc[:700, -1].values.astype(int)
X_test, y_test = df_shuffled.iloc[700:842, :-1].values, df_shuffled.iloc[700:842, -1].values.astype(int)
X_val, y_val = df_shuffled.iloc[842:, :-1].values, df_shuffled.iloc[842:, -1].values.astype(int)

# Size Check
X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((700, 30), (700,), (142, 30), (142,), (142, 30), (142,))

# %%
# Instantiate a model object
log_reg = LogisticRegression()

# Hyperparameter Tuning
param_grid = {
    'C': [0.1, 1, 10, 100], 
    'penalty': ['l1', 'l2'], 
    'solver': ['liblinear']
}

# Grid Search for best logistic regression model:
log_cv = GridSearchCV(log_reg, param_grid, cv=5, scoring='f1', verbose=1)

# %%
# Fit the model
# %%time
log_cv.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# CPU times: user 1.86 s, sys: 50.7 ms, total: 1.91 s
# Wall time: 2.06 s
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'C': [0.1, 1, 10, 100], 'penalty': ['l1', 'l2'],
#                          'solver': ['liblinear']},
#              scoring='f1', verbose=1)

# %%
# Best LogReg model:
log_reg_cv = log_cv.best_estimator_

# %%
# Get the predicted probabilities for the positive class (class 1) on validation set
y_val_pred_prob = log_reg_cv.predict_proba(X_val)[:, 1]

# Compute ROC curve and ROC area for validation set
fpr_val, tpr_val, _ = roc_curve(y_val, y_val_pred_prob)
roc_auc_val = auc(fpr_val, tpr_val)

# Plot ROC curve for validation set
plt.figure()
lw = 2
plt.plot(fpr_val, tpr_val, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc_val)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve - Validation Set')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# - **ROC curve**: The orange line represents the ROC curve, which shows the trade-off between the TPR and FPR at various threshold settings. The better the model is at distinguishing between the positive and negative classes, the closer the curve will be to the upper left corner of the graph.
# - **Area Under the Curve (AUC)**: The AUC value is a measure of the model’s overall ability to discriminate between positive and negative classes. An AUC of 0.91, as shown in the graph, is quite high, indicating that the model has good discriminatory ability.
# - **Dotted Line**: The blue dotted line represents a random classifier (AUC = 0.5), where the true positives and false positives are equal across all thresholds. The further the ROC curve is above this line, the better the model performs compared to a random guess.

# %%
y_pred_log_reg = log_reg_cv.predict(X_val)
print(classification_report(y_val, y_pred_log_reg, target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       0.93      0.96      0.94        77
#        Fraud       0.95      0.91      0.93        65
#
#     accuracy                           0.94       142
#    macro avg       0.94      0.93      0.94       142
# weighted avg       0.94      0.94      0.94       142

# %% [markdown]
# The classification report indicates that the model performs well in identifying fraudulent transactions, with high precision (0.90) and recall (0.81). However, it also maintains good balance in identifying non-fraudulent transactions, with a precision of 0.79 and recall of 0.89. Both classes have decent F1-scores: 0.83 for "Not Fraud" and 0.86 for "Fraud.

# %%
# Function for plotting confusion matrix
def conf_matrix_plot(model, x_data, y_data):
    '''
    Accepts as argument model object, X data (test or validate), and y data (test or validate). 
    Returns a plot of confusion matrix for predictions on y data.
    ''' 
  
    model_pred = model.predict(x_data)
    cm = confusion_matrix(y_data, model_pred, labels=model.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                             display_labels=model.classes_)
  
    disp.plot()
    plt.title('Confusion Matrix for Credit Card Transactions', size = 12)
    plt.show()

# %%
# Plotting Confusion matrix using function
conf_matrix_plot(log_reg_cv, X_val, y_val)

# %% [markdown]
# - Model has a particularly high precision for detecting fraudulent transactions, which is crucial for a fraud detection system to minimize the number of false alerts(6) that would be costly and inconvenient for customers.
# - The recall for fraudulent transactions is also high, meaning it's capable of catching a good portion of fraudulent activities. However, there's room for improvement since false negative(6) rate for fraud means some fraudulent transactions are still being missed.
# - The F1-score is quite balanced, especially for the "Fraud" class, which suggests that the model has achieved a good balance between precision and recall for this class.

# %%
# Evalution metrics
accuracy = accuracy_score(y_val, y_pred_log_reg)
precision = precision_score(y_val, y_pred_log_reg)
recall = recall_score(y_val, y_pred_log_reg)
f1 = f1_score(y_val, y_pred_log_reg)

# Create a DataFrame to store the results
results_log_reg = pd.DataFrame({
    'Model': ['Logistic Regression CV'],
    'Accuracy': [accuracy],
    'Precision': [precision],
    'Recall': [recall],
    'F1 Score': [f1]
})

# %%
results_log_reg_df = results_log_reg.copy()
results_log_reg_df
# Out:
#                     Model  Accuracy  Precision    Recall  F1 Score
# 0  Logistic Regression CV   0.93662   0.951613  0.907692  0.929134

# %% [markdown]
# **We will use this dataframe to concat results from other models and then choose our champion model to make predictions on our y_test set**

# %% [markdown]
# ## Decision Tree using Cross validation

# %%
# Instantiate the classifier
tuned_decision_tree = DecisionTreeClassifier(random_state = 42)

# Assign a dictionary of hyper parameters to search over
tree_para = {'max_depth':[4,5,6,7,8,9,10],
             'min_samples_leaf': [2, 5, 10, 20, 50],
             'min_samples_split': [2, 4, 6, 8]}

# Assign a dictionary of scoring metrics to capture
scoring = {'accuracy', 'precision', 'recall', 'f1'}

# Instantiate the GridSearch
clf = GridSearchCV(tuned_decision_tree, # The classifier (tuned_decision_tree)
                   tree_para,           # dictionary of hyper parameters to search over
                   scoring = scoring,   # dictionary of scoring metrics (scoring)
                   cv=5,                # cross-validation folds you want
                   refit="f1")          # The scoring metric that you want GridSearch to use when it selects the "best" model (i.e., the model that performs best on average over all 												   validation folds) (refit='f1'*)

# %%
# %%time
# Fit the model
clf.fit(X_train, y_train)
# Out:
# CPU times: user 3.83 s, sys: 12.6 ms, total: 3.84 s
# Wall time: 3.86 s
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42),
#              param_grid={'max_depth': [4, 5, 6, 7, 8, 9, 10],
#                          'min_samples_leaf': [2, 5, 10, 20, 50],
#                          'min_samples_split': [2, 4, 6, 8]},
#              refit='f1', scoring={'recall', 'precision', 'accuracy', 'f1'})

# %%
# Best estimator 
dtree_cv_best = clf.best_estimator_
dtree_cv_best
# Out:
# DecisionTreeClassifier(max_depth=9, min_samples_leaf=2, min_samples_split=6,
#                        random_state=42)

# %%
# Get the predicted probabilities for the positive class (class 1) on validation set
y_val_pred_prob = dtree_cv_best.predict_proba(X_val)[:, 1]

# Compute ROC curve and ROC area for validation set
fpr_val, tpr_val, _ = roc_curve(y_val, y_val_pred_prob)
roc_auc_val = auc(fpr_val, tpr_val)

# Plot ROC curve for validation set
plt.figure()
lw = 2
plt.plot(fpr_val, tpr_val, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc_val)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve - Validation Set')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# **Observations**
# - The AUC of 0.91 suggests the model has a high ability to distinguish between classes.
# - The ROC curve stays well above the diagonal line of no-discrimination, confirming good model sensitivity.
# - The closer the curve follows the left-hand border and then the top border of the ROC space, the more accurate the test.

# %%
# Classificaiton report
y_pred_dtree = dtree_cv_best.predict(X_val)
print(classification_report(y_val, y_pred_dtree, target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       0.93      0.88      0.91        77
#        Fraud       0.87      0.92      0.90        65
#
#     accuracy                           0.90       142
#    macro avg       0.90      0.90      0.90       142
# weighted avg       0.90      0.90      0.90       142

# %% [markdown]
# **Observations**
# - Moderate precision for fraud detection at 0.87: the model is accurate when it predicts fraud.
# - Moderate recall for non-fraud at 0.88: it correctly identifies most non-fraudulent transactions.
# - The F1-score is balanced for both classes, slightly favoring no fraud detection at 0.91.
# - The overall accuracy of the model is 0.90, which is the proportion of total transactions correctly classified.
# - There is still room for improvement since we have imbalances in the predictions. We will use a Random forest model further for the improvement

# %%
# Confusion Matrix
conf_matrix_plot(dtree_cv_best, X_val, y_val)

# %% [markdown]
# - The model correctly identified 68 transactions as legitimate (true negatives).
# - It correctly identified 60 transactions as fraudulent (true positives).
# - The model incorrectly flagged 9 legitimate transactions as fraudulent (false positives).
# - It failed to detect 5 fraudulent transactions, mistaking them for legitimate (false negatives).

# %%
# Evalution metrics
accuracy_1 = accuracy_score(y_val, y_pred_dtree)
precision_1 = precision_score(y_val, y_pred_dtree)
recall_1 = recall_score(y_val, y_pred_dtree)
f1_1 = f1_score(y_val, y_pred_dtree)

# Create a DataFrame to store the results
results_dtree = pd.DataFrame({
    'Model': ['Decision Tree CV'],
    'Accuracy': [accuracy_1],
    'Precision': [precision_1],
    'Recall': [recall_1],
    'F1 Score': [f1_1]
})

# %%
results_dtree_df = results_dtree.copy()
results_dtree_df
# Out:
#               Model  Accuracy  Precision    Recall  F1 Score
# 0  Decision Tree CV  0.901408   0.869565  0.923077  0.895522

# %% [markdown]
# ## Random Forest using Cross Validation

# %%
# Instantiate model object
rf = RandomForestClassifier(random_state=0)

# Custom paramters
cv_params = {'max_depth': [5, 7, None],
             'max_features': [0.3, 0.6],
             'max_features': ['auto'],
             'max_samples': [0.7],
             'min_samples_leaf': [1,2],
             'min_samples_split': [2,3],
             'n_estimators': [75,100,200],
             }

# Assign a dictionary of scoring metrics to capture
scoring = {'accuracy', 'precision', 'recall', 'f1'}

# Instantiate the GridSearch
rf_cv = GridSearchCV(rf,  # The classifier (tuned_decision_tree)
                    cv_params,            # Dictionary of hyperparameters to search over
                    scoring=scoring,     # Dictionary of scoring metrics
                    cv=5,                 # Number of cross-validation folds
                    refit="f1",
                    verbose = 1)           # The scoring metric for refitting

# %%
# %%time
# Fit the model
rf_cv.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# CPU times: user 22.3 s, sys: 112 ms, total: 22.4 s
# Wall time: 22.4 s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=0),
#              param_grid={'max_depth': [5, 7, None], 'max_features': ['auto'],
#                          'max_samples': [0.7], 'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 3],
#                          'n_estimators': [75, 100, 200]},
#              refit='f1', scoring={'recall', 'precision', 'accuracy', 'f1'},
#              verbose=1)

# %%
# Best estimator 
rf_cv_best = rf_cv.best_estimator_
rf_cv_best
# Out:
# RandomForestClassifier(max_depth=7, max_samples=0.7, min_samples_leaf=2,
#                        n_estimators=75, random_state=0)

# %%
# Get the predicted probabilities for the positive class (class 1) on validation set
y_val_pred_prob = rf_cv_best.predict_proba(X_val)[:, 1]

# Compute ROC curve and ROC area for validation set
fpr_val, tpr_val, _ = roc_curve(y_val, y_val_pred_prob)
roc_auc_val = auc(fpr_val, tpr_val)

# Plot ROC curve for validation set
plt.figure()
lw = 2
plt.plot(fpr_val, tpr_val, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc_val)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve - Validation Set')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# **Observations**
# - The AUC of 0.93 suggests the model has a high ability to distinguish between classes.
# - The ROC curve stays well above the diagonal line of no-discrimination, confirming good model sensitivity.
# - The closer the curve follows the left-hand border and then the top border of the ROC space, the more accurate the test.

# %%
# Classification report
y_pred_rf = rf_cv_best.predict(X_val)
print(classification_report(y_val, y_pred_rf, target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       0.90      1.00      0.94        77
#        Fraud       1.00      0.86      0.93        65
#
#     accuracy                           0.94       142
#    macro avg       0.95      0.93      0.94       142
# weighted avg       0.94      0.94      0.94       142

# %% [markdown]
# - The model has a high precision of 0.93 for non-fraudulent transactions, meaning it has a low false positive rate for this class.
# - It has a slightly lower precision for fraudulent transactions (0.87), indicating more legitimate transactions are mistakenly labeled as fraud compared to the converse.
# - The recall for fraudulent transactions is high (0.92), suggesting the model is adept at identifying most fraudulent activities.
# - The overall F1-scores are very close (0.91 for non-fraud and 0.90 for fraud), showing a balanced performance between precision and recall across both classes.

# %%
# Confusion Matrix
conf_matrix_plot(rf_cv_best, X_val, y_val)

# %%
# Evaluation metrics
accuracy = accuracy_score(y_val, y_pred_rf)
precision = precision_score(y_val, y_pred_rf)
recall = recall_score(y_val, y_pred_rf)
f1 = f1_score(y_val, y_pred_rf)

# Create a DataFrame to store the results
results_rf = pd.DataFrame({
    'Model': ['Random Forest CV'],
    'Accuracy': [accuracy],
    'Precision': [precision],
    'Recall': [recall],
    'F1 Score': [f1]
})

# %%
results_rf_df = results_rf.copy()
results_rf_df
# Out:
#               Model  Accuracy  Precision    Recall  F1 Score
# 0  Random Forest CV   0.93662        1.0  0.861538   0.92562

# %%
# Combining all our results of the three models:
final_results = pd.concat([results_log_reg_df, results_dtree_df, results_rf_df], axis=0)
final_results
# Out:
#                     Model  Accuracy  Precision    Recall  F1 Score
# 0  Logistic Regression CV  0.936620   0.951613  0.907692  0.929134
# 0        Decision Tree CV  0.901408   0.869565  0.923077  0.895522
# 0        Random Forest CV  0.936620   1.000000  0.861538  0.925620

# %% [markdown]
# ## Champion model: Logistic Regression using Cross validation

# %%
# Champion model:
champion_model = log_reg_cv

# Making predicitons on the final test set
y_final_pred = champion_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Assuming 'champion_model' is your trained and selected model and 'X_test' is your test data.
y_final_pred = champion_model.predict(X_test)

# Calculate various performance metrics
accuracy = accuracy_score(y_test, y_final_pred)
precision = precision_score(y_test, y_final_pred)
recall = recall_score(y_test, y_final_pred)
f1 = f1_score(y_test, y_final_pred)

# Print the performance metrics
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Accuracy: 0.9366
# Precision: 0.9412
# Recall: 0.9275
# F1 Score: 0.9343

# %%
# Classification report
y_pred_final = log_reg_cv.predict(X_test)
print(classification_report(y_test, y_pred_final, target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       0.93      0.95      0.94        73
#        Fraud       0.94      0.93      0.93        69
#
#     accuracy                           0.94       142
#    macro avg       0.94      0.94      0.94       142
# weighted avg       0.94      0.94      0.94       142

# %%
# Confusion matrix
conf_matrix_plot(champion_model, X_test, y_test)

# %% [markdown]
# # Technical Report: Credit Card Fraud Detection Model Comparison
#
# ## Executive Summary
# This report presents the evaluation of three machine learning models for the purpose of detecting credit card fraud. The models assessed include Logistic Regression with Cross-Validation (LR CV), Decision Tree with Cross-Validation (DT CV), and Random Forest with Cross-Validation (RF CV).
#
# ## Performance Metrics Summary
# - **Logistic Regression CV** shows a commendable balance between all the metrics, with an F1 Score of 92.9134%.
# - **Decision Tree CV** exhibits the least performance across all metrics except for Recall, indicating a good ability to detect fraud but at the cost of more false positives.
# - **Random Forest CV** presents a perfect Precision of 100%, indicating no false positives, but it has a lower Recall, which could lead to missing out on some fraudulent transactions.
#
# ## Model Selection
# | Model                   | Accuracy | Precision | Recall | F1 Score |
# |-------------------------|----------|-----------|--------|----------|
# | **Logistic Regression CV(Champion)**  | 93.66%   | 95.16%    | 90.77% | 92.91%   |
# | Decision Tree CV        | 90.14%   | 86.96%    | 92.31% | 89.55%   |
# | Random Forest CV        | 93.66%   | 100%      | 86.15% | 92.56%   |
#
# While Random Forest CV exhibits no false positives, its lower Recall score suggests that it might miss a higher number of fraudulent transactions. On the other hand, Logistic Regression CV provides a balanced approach, with high marks in all metrics, especially the F1 Score, which is crucial for a problem where both Precision and Recall are important.
#
# ## Test Set Performance Evaluation
# Upon final testing, the champion model, Logistic Regression CV, was evaluated on the unseen test set. The model demonstrated robust performance with the following metrics:
# - Accuracy: 93.66%
# - Precision: 94.12%
# - Recall: 92.75%
# - F1 Score: 93.43%
#
# These results confirm the model’s efficacy in providing a balanced approach to fraud detection, with strong performance across all key metrics.
#
# ## Recommendation
# Given the importance of both catching as many frauds as possible (Recall) and minimizing the disturbance to non-fraudulent transactions (Precision), the Logistic Regression CV model is recommended as the champion model for deployment in credit card fraud detection systems.
#
# ## Future Considerations
# Future work should consider a cost-benefit analysis of false positives versus false negatives in a financial context to better tailor the model to the business objectives. Additionally, continuous monitoring of the model's performance should be instituted to promptly adjust for changes in fraud trends.
